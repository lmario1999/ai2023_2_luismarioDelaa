# %% [markdown]
# <a href="https://colab.research.google.com/github/lmario1999/ai2023_2_luismarioDelaa/blob/main/TareaPandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

tmp=pd.Series(data=[100,200,300,400],index=['carlos','juan','mario','rosita'])
print(tmp)
# Out:
# carlos    100
# juan      200
# mario     300
# rosita    400
# dtype: int64

# %%
tmp.shape
# Out:
# (4,)

# %%
print(tmp['mario'])
# Out:
# 300

# %%
tmp*2
# Out:
# carlos    200
# juan      400
# mario     600
# rosita    800
# dtype: int64

# %%
print(tmp[[1,2,3]])
# Out:
# juan      200
# mario     300
# rosita    400
# dtype: int64

# %%
tmp.index
# Out:
# Index(['carlos', 'juan', 'mario', 'rosita'], dtype='object')

# %%
my_dict={'name':'john','age':25, 'city':'NewYork'}

# %%
aux={'one':pd.Series([1,2,3],index=['apple','ball','clock']),
     'two':pd.Series([4,5,6],index=['perro','gato','conejo'])}

# %%
df = pd.DataFrame(aux)

print(df)
# Out:
#         one  two
# apple   1.0  NaN
# ball    2.0  NaN
# clock   3.0  NaN
# conejo  NaN  6.0
# gato    NaN  5.0
# perro   NaN  4.0

# %%
df.index
# Out:
# Index(['apple', 'ball', 'clock', 'conejo', 'gato', 'perro'], dtype='object')

# %%
df.columns
# Out:
# Index(['one', 'two'], dtype='object')

# %%
df['three']=df['one']*df['two']

# %%
df['four']=df['one']*df['two']
df
# Out:
#         one  two  three  four
# apple   1.0  NaN    NaN   NaN
# ball    2.0  NaN    NaN   NaN
# clock   3.0  NaN    NaN   NaN
# conejo  NaN  6.0    NaN   NaN
# gato    NaN  5.0    NaN   NaN
# perro   NaN  4.0    NaN   NaN

# %%
df['filtro']=df['one']>2
df
# Out:
#         one  two  three  four  filtro
# apple   1.0  NaN    NaN   NaN   False
# ball    2.0  NaN    NaN   NaN   False
# clock   3.0  NaN    NaN   NaN    True
# conejo  NaN  6.0    NaN   NaN   False
# gato    NaN  5.0    NaN   NaN   False
# perro   NaN  4.0    NaN   NaN   False

# %%
del df['three']

df2=df.pop('four')

df
# Out:
#         one  two  filtro
# apple   1.0  NaN   False
# ball    2.0  NaN   False
# clock   3.0  NaN    True
# conejo  NaN  6.0   False
# gato    NaN  5.0   False
# perro   NaN  4.0   False

# %%
tags=pd.read_csv('https://raw.githubusercontent.com/ChicagoBoothML/DATA___MovieLens___20M/master/tags.csv')
ratings=pd.read_csv('https://raw.githubusercontent.com/ChicagoBoothML/DATA___MovieLens___20M/master/ratings01.csv')
movies = pd.read_csv('https://raw.githubusercontent.com/ChicagoBoothML/DATA___MovieLens___20M/master/movies.csv')

# %%
tags.shape
# Out:
# (465564, 4)

# %%
tags.columns
# Out:
# Index(['userId', 'movieId', 'tag', 'timestamp'], dtype='object')

# %%
tags[:10]
# Out:
#    userId  movieId               tag   timestamp
# 0      18     4141       Mark Waters  1240597180
# 1      65      208         dark hero  1368150078
# 2      65      353         dark hero  1368150079
# 3      65      521     noir thriller  1368149983
# 4      65      592         dark hero  1368150078
# 5      65      668         bollywood  1368149876
# 6      65      898  screwball comedy  1368150160
# 7      65     1248     noir thriller  1368149983
# 8      65     1391              mars  1368150055
# 9      65     1617          neo-noir  1368150217

# %%
print(tags['tag'][:10])
# Out:
# 0         Mark Waters
# 1           dark hero
# 2           dark hero
# 3       noir thriller
# 4           dark hero
# 5           bollywood
# 6    screwball comedy
# 7       noir thriller
# 8                mars
# 9            neo-noir
# Name: tag, dtype: object

# %%
movies.head(10)
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
# 5        6                         Heat (1995)
# 6        7                      Sabrina (1995)
# 7        8                 Tom and Huck (1995)
# 8        9                 Sudden Death (1995)
# 9       10                    GoldenEye (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy
# 5                        Action|Crime|Thriller
# 6                               Comedy|Romance
# 7                           Adventure|Children
# 8                                       Action
# 9                    Action|Adventure|Thriller

# %%
ratings.head(10)
# Out:
#    userId  movieId  rating   timestamp
# 0       1        2     3.5  1112486027
# 1       1       29     3.5  1112484676
# 2       1       32     3.5  1112484819
# 3       1       47     3.5  1112484727
# 4       1       50     3.5  1112484580
# 5       1      112     3.5  1094785740
# 6       1      151     4.0  1094785734
# 7       1      223     4.0  1112485573
# 8       1      253     4.0  1112484940
# 9       1      260     4.0  1112484826

# %%
tags.tail(10)
# Out:
#         userId  movieId                               tag   timestamp
# 465554  138446     3489                visually appealing  1358983822
# 465555  138446     7045                   family friendly  1358983660
# 465556  138446     7045  Scary Movies To See on Halloween  1358983660
# 465557  138446     7164                         Peter Pan  1358983855
# 465558  138446     7164                visually appealing  1358983855
# 465559  138446    55999                           dragged  1358983772
# 465560  138446    55999                     Jason Bateman  1358983778
# 465561  138446    55999                            quirky  1358983778
# 465562  138446    55999                               sad  1358983772
# 465563  138472      923                     rise to power  1194037967

# %%
movies.tail(10)
# Out:
#        movieId                                              title  \
# 27268   131241                           Ants in the Pants (2000)
# 27269   131243                Werner - Gekotzt wird später (2003)
# 27270   131248                              Brother Bear 2 (2006)
# 27271   131250                              No More School (2000)
# 27272   131252  Forklift Driver Klaus: The First Day on the Jo...
# 27273   131254                       Kein Bund für's Leben (2007)
# 27274   131256                      Feuer, Eis & Dosenbier (2002)
# 27275   131258                                 The Pirates (2014)
# 27276   131260                                Rentun Ruusu (2001)
# 27277   131262                                   Innocence (2014)
#
#                                             genres
# 27268                               Comedy|Romance
# 27269                             Animation|Comedy
# 27270  Adventure|Animation|Children|Comedy|Fantasy
# 27271                                       Comedy
# 27272                                Comedy|Horror
# 27273                                       Comedy
# 27274                                       Comedy
# 27275                                    Adventure
# 27276                           (no genres listed)
# 27277                     Adventure|Fantasy|Horror
